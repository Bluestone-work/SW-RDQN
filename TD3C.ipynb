# %%
import numpy as np
import random
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm
from collections import deque
import copy
import pygame
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import numpy as np
import random

class GridWorld:
    def __init__(self, grid_map, start, goal, max_steps=50000, goal_list=None):
        """
        初始化 GridWorld 环境
        """
        self.grid_map = grid_map
        self.base_grid_map = grid_map.copy()  # 保存基础地图（无动态障碍物）
        self.rows, self.cols = grid_map.shape
        self.max_steps = max_steps
        self.goal_list = goal_list if goal_list else []  # 目标点列表
        
        if start is not None and goal is not None:
            self.start = start
            self.goal = goal
            self.agent_pos = np.array(self.start, dtype=float)
            self.distance = np.linalg.norm(self.agent_pos - np.array(self.goal))
        else:
            self.reset_dynamic(start, goal)

    def reset_dynamic(self, num_obstacles=30, num_dynamic_obstacles=10):
        """
        每次 reset 时动态生成障碍物，并使用传入的起点和目标，或者随机生成。
        """
        self.grid_map = self.base_grid_map.copy()

        # 固定障碍物初始化
        valid_positions = [
            (i, j) for i in range(1, self.rows - 1) for j in range(1, self.cols - 1)
            if self.grid_map[i, j] == 0
        ]
        random_obstacles = random.sample(valid_positions, num_obstacles)
        for x, y in random_obstacles:
            self.grid_map[x, y] = 1

        # 动态障碍物初始化
        self.dynamic_obstacles = []
        for _ in range(num_dynamic_obstacles):
            x, y = random.choice(valid_positions)
            direction = random.choice(['up', 'down', 'left', 'right'])
            speed = random.randint(1, 2)

            self.dynamic_obstacles.append({
                'position': (x, y),
                'direction': direction,
                'speed': speed
            })

        # 确保起点和目标点不在障碍物中
        self.valid_positions = [
            (i, j) for i in range(1, self.rows - 1) for j in range(1, self.cols - 1)
            if self.grid_map[i, j] == 0
        ]
        self.agent_pos = np.array(self.start, dtype=float)
        self.steps = 0
        self.distance = np.linalg.norm(self.agent_pos - np.array(self.goal))

    def reset(self):
        """
        重置环境到初始状态
        """
        self.reset_dynamic()
        self.goal_list_copy = self.goal_list.copy()
        self.current_goal_index = 0
        self.goal = self.goal_list[self.current_goal_index] if self.goal_list else self.goal
        return self.get_state()

    def get_state(self):
        """
        获取当前状态
        """
        nearby_grid = np.ones((7, 7), dtype=int)
        x_min, x_max = max(0, int(self.agent_pos[0] - 3)), min(self.rows, int(self.agent_pos[0] + 4))
        y_min, y_max = max(0, int(self.agent_pos[1] - 3)), min(self.cols, int(self.agent_pos[1] + 4))
        r_min, r_max = 3 - (int(self.agent_pos[0]) - x_min), 3 + (x_max - int(self.agent_pos[0]))
        c_min, c_max = 3 - (int(self.agent_pos[1]) - y_min), 3 + (y_max - int(self.agent_pos[1]))

        nearby_grid[r_min:r_max, c_min:c_max] = self.grid_map[x_min:x_max, y_min:y_max]
        nearby_flat = nearby_grid.flatten()

        dx = self.goal[0] - self.agent_pos[0]
        dy = self.goal[1] - self.agent_pos[1]
        distance_to_goal = np.sqrt(dx**2 + dy**2)
        angle_to_goal = np.arctan2(dy, dx)

        # 当前状态
        current_state = np.concatenate(([distance_to_goal, angle_to_goal], nearby_flat))
        return current_state
    
    def step(self, action):
        """
        执行动作并更新环境状态
        """
        # 动作有效性检查（假设动作范围为 [-1, 1]）
        action = np.clip(action, -1, 1)
        
        # 将连续动作映射到移动量，假设最大移动量为 1 单元
        delta = action  # 可以根据需要调整比例

        # 更新位置
        new_pos = self.agent_pos + delta
        new_pos = np.clip(new_pos, 0, [self.rows - 1, self.cols - 1])

        # 检查是否碰到障碍物
        int_new_pos = tuple(new_pos.astype(int))
        if self.grid_map[int_new_pos] == 1:
            reward = -3.0
            done = True
            return self.get_state(), reward, done

        self.agent_pos = new_pos
        reward = -0.5
        done = False

        # 计算距离变化
        next_distance = np.linalg.norm(self.agent_pos - np.array(self.goal))
        if self.distance > next_distance:
            reward += 0.6
        else:
            reward -= 0.4
        self.distance = next_distance

        # 计算对齐奖励
        action_vector = np.array(delta)
        goal_vector = np.array(self.goal) - self.agent_pos
        goal_vector_norm = goal_vector / (np.linalg.norm(goal_vector) + 1e-5)
        
        if np.linalg.norm(goal_vector) > 0.1:
            alignment_reward = np.dot(action_vector, goal_vector_norm)
        else:
            alignment_reward = 0
        
        reward += alignment_reward * 0.4

        # 检查是否到达目标
        if self.distance < 0.5:
            reward += 10
            if self.current_goal_index + 1 < len(self.goal_list):
                self.current_goal_index += 1
                self.goal = self.goal_list[self.current_goal_index]  
            else:
                done = True

        # 更新动态障碍物的位置
        for obstacle in self.dynamic_obstacles:
            x, y = obstacle['position']
            direction = obstacle['direction']
            speed = obstacle['speed']
            
            if direction == 'up':
                new_ob_pos = (x - speed, y)
            elif direction == 'down':
                new_ob_pos = (x + speed, y)
            elif direction == 'left':
                new_ob_pos = (x, y - speed)
            elif direction == 'right':
                new_ob_pos = (x, y + speed)
            
            # 边界检查
            if 0 <= new_ob_pos[0] < self.rows and 0 <= new_ob_pos[1] < self.cols:
                if self.grid_map[new_ob_pos] == 1:
                    # 反向移动
                    if direction == 'up':
                        obstacle['direction'] = 'down'
                    elif direction == 'down':
                        obstacle['direction'] = 'up'
                    elif direction == 'left':
                        obstacle['direction'] = 'right'
                    elif direction == 'right':
                        obstacle['direction'] = 'left'
                else:
                    # 更新障碍物位置
                    self.grid_map[x, y] = 0  # 清除旧位置
                    self.grid_map[new_ob_pos] = 1  # 设置新位置
                    obstacle['position'] = new_ob_pos

        # 计算最小障碍物距离
        min_distance_to_obstacle = float('inf')
        for i in range(self.rows):
            for j in range(self.cols):
                if self.grid_map[i, j] == 1:  # 障碍物
                    distance_to_obstacle = np.linalg.norm(np.array([i, j]) - self.agent_pos)
                    min_distance_to_obstacle = min(min_distance_to_obstacle, distance_to_obstacle)

        # 奖励：距离障碍物越近，惩罚越大
        if min_distance_to_obstacle == 1.0:
            reward -= 2.0
        elif min_distance_to_obstacle <= 2.0:
            reward -= 1.5
        elif min_distance_to_obstacle <= 3.0:
            reward -= 0.2
        else:
            reward -= 0.01

        # 检查是否碰到动态障碍物
        for obstacle in self.dynamic_obstacles:
            if tuple(self.agent_pos.astype(int)) == obstacle['position']:
                reward -= 3.0
                done = True
                return self.get_state(), reward, done

        self.steps += 1
        if self.steps >= self.max_steps:
            done = True
            reward -= 10

        return self.get_state(), reward, done

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action, hidden_dim=256):
        super(Actor, self).__init__()
        self.l1 = nn.Linear(state_dim, hidden_dim)
        self.l2 = nn.Linear(hidden_dim, hidden_dim)
        self.l3 = nn.Linear(hidden_dim, action_dim)
        
        self.max_action = max_action

    def forward(self, state):
        a = F.relu(self.l1(state))
        a = F.relu(self.l2(a))
        a = torch.tanh(self.l3(a))  # 输出范围 [-1, 1]
        return a * self.max_action  # 缩放到动作空间范围

# %%
class Critic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim=256):
        super(Critic, self).__init__()
        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, hidden_dim)
        self.l2 = nn.Linear(hidden_dim, hidden_dim)
        self.l3 = nn.Linear(hidden_dim, 1)
        
        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, hidden_dim)
        self.l5 = nn.Linear(hidden_dim, hidden_dim)
        self.l6 = nn.Linear(hidden_dim, 1)

    def forward(self, state, action):
        sa = torch.cat([state, action], dim=1)
        
        # Q1 forward
        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        
        # Q2 forward
        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        
        return q1, q2

    def Q1(self, state, action):
        sa = torch.cat([state, action], dim=1)
        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1

# %%
from collections import deque
import random

class ReplayBuffer:
    def __init__(self, max_size=1_000_000):
        self.buffer = deque(maxlen=max_size)
    
    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = map(np.stack, zip(*batch))
        return state, action, reward, next_state, done
    
    def size(self):
        return len(self.buffer)

# %%
class TD3:
    def __init__(
        self,
        state_dim,
        action_dim,
        max_action,
        actor_lr=5e-3,
        critic_lr=1e-4,
        gamma=0.99,
        tau=0.005,
        policy_noise=0.2,
        noise_clip=0.5,
        policy_freq=2,
    ):
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target.load_state_dict(self.actor.state_dict())
        
        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = Critic(state_dim, action_dim).to(device)
        self.critic_target.load_state_dict(self.critic.state_dict())
        
        self.max_action = max_action
        self.gamma = gamma
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq
        
        self.replay_buffer = ReplayBuffer()
        
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=actor_lr)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=critic_lr)
        
        self.total_it = 0

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()
    
    def train(self, batch_size=256):
        if self.replay_buffer.size() < batch_size:
            return
        
        state, action, reward, next_state, done = self.replay_buffer.sample(batch_size)
        
        state = torch.FloatTensor(state).to(device)
        action = torch.FloatTensor(action).to(device)
        reward = torch.FloatTensor(reward).unsqueeze(1).to(device)
        next_state = torch.FloatTensor(next_state).to(device)
        done = torch.FloatTensor(done).unsqueeze(1).to(device)
        
        with torch.no_grad():
            # 选择下一个动作，加入噪声
            noise = (torch.randn_like(action) * self.policy_noise).clamp(-self.noise_clip, self.noise_clip)
            next_action = (self.actor_target(next_state) + noise).clamp(-self.max_action, self.max_action)
            
            # 计算目标 Q 值
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + ((1 - done) * self.gamma * target_Q).detach()
        
        # 当前 Q 值
        current_Q1, current_Q2 = self.critic(state, action)
        
        # 计算 critic 的损失
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
        
        # 优化 critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()
        
        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:
            # 计算 actor 的损失
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
            
            # 优化 actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()
            
            # 更新目标网络
            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
            
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
        
        self.total_it += 1
    
    def save(self, filename):
        torch.save(self.actor.state_dict(), filename + "_actor.pth")
        torch.save(self.critic.state_dict(), filename + "_critic.pth")
    
    def load(self, filename):
        self.actor.load_state_dict(torch.load(filename + "_actor.pth"))
        self.critic.load_state_dict(torch.load(filename + "_critic.pth"))

# %%
import os
import time
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm

def train_td3_agent(env, agent, episodes=1000, max_steps=1000, save_path="td3_model", log_dir="runs"):
    """
    使用 TD3 算法训练智能体，并记录训练信息到 TensorBoard。
    
    :param env: 环境实例 (GridWorld)
    :param agent: 智能体实例 (TD3)
    :param episodes: 训练的总回合数
    :param max_steps: 每回合的最大步数
    :param save_path: 模型保存路径（不带扩展名）
    :param log_dir: TensorBoard 日志保存目录
    """
    # 初始化 TensorBoard 日志记录器
    run_id = time.strftime("%Y%m%d-%H%M%S")
    log_dir = os.path.join(log_dir, f"run_{run_id}")
    os.makedirs(log_dir, exist_ok=True)
    writer = SummaryWriter(log_dir)
    
    best_reward = -float('inf')  # 记录最佳奖励
    step_counter = 0  # 全局步数计数器
    all_rewards = []  # 保存所有回合奖励
    all_losses = []  # 保存所有回合平均损失
    
    # 使用 tqdm 进度条显示训练过程
    with tqdm(total=episodes, desc="训练进度", unit="episode") as pbar:
        for episode in range(1, episodes + 1):
            state = env.reset()
            done = False
            total_reward = 0  # 当前回合总奖励
            episode_steps = 0  # 当前回合步数计数
            losses = []  # 当前回合的损失列表

            while not done:
                # 选择动作
                action = agent.select_action(state)
                
                # 环境执行动作并返回新状态、奖励和是否结束
                next_state, reward, done = env.step(action)
                
                # 存储经验
                agent.replay_buffer.add(state, action, reward, next_state, done)
                
                # 训练模型
                actor_loss, critic_loss = agent.train(batch_size=256)
                
                # 记录损失
                if actor_loss is not None and critic_loss is not None:
                    losses.append((actor_loss, critic_loss))
                
                state = next_state
                total_reward += reward
                episode_steps += 1
                step_counter += 1

                # 如果达到最大步数，则结束当前回合
                if episode_steps >= max_steps:
                    done = True

            # 记录奖励和损失到 TensorBoard
            writer.add_scalar("Reward/Episode", total_reward, episode)
            if actor_loss is not None and critic_loss is not None:
                avg_actor_loss = np.mean([loss[0] for loss in losses])
                avg_critic_loss = np.mean([loss[1] for loss in losses])
                writer.add_scalar("Loss/Actor", avg_actor_loss, episode)
                writer.add_scalar("Loss/Critic", avg_critic_loss, episode)
                all_losses.append((avg_actor_loss, avg_critic_loss))
            all_rewards.append(total_reward)
            
            # 更新 tqdm 进度条信息
            pbar.set_postfix({"总奖励": total_reward})
            pbar.update(1)
            
            # 如果当前回合的奖励是历史最高，则保存模型
            if total_reward > best_reward:
                best_reward = total_reward
                agent.save_model(save_path)
            
            # 每 10 个回合刷新 TensorBoard 数据
            if episode % 10 == 0:
                writer.flush()
    
    # 保存最终模型
    agent.save_model(save_path)
    
    # 关闭 TensorBoard 日志记录器
    writer.close()
    
    print(f"训练完成，模型已保存到 {save_path}_actor.pth 和 {save_path}_critic.pth")
    
    # 保存奖励和损失数据以便后续绘图
    np.save(os.path.join(log_dir, "rewards.npy"), all_rewards)
    np.save(os.path.join(log_dir, "actor_losses.npy"), [loss[0] for loss in all_losses])
    np.save(os.path.join(log_dir, "critic_losses.npy"), [loss[1] for loss in all_losses])

# %%
def train_td3(env, agent, episodes=1000, max_steps=1000, batch_size=256, save_every=100):
    import numpy as np
    import torch
    import random

    rewards_history = []
    for episode in range(1, episodes + 1):
        state = env.reset()
        episode_reward = 0
        for step in range(max_steps):
            # 选择动作
            action = agent.select_action(np.array(state))
            
            # 添加探索噪声
            noise = np.random.normal(0, 0.1, size=agent.actor.l3.out_features)
            action = (action + noise).clip(-agent.max_action, agent.max_action)
            
            # 执行动作
            next_state, reward, done = env.step(action)
            
            # 存储经验
            agent.replay_buffer.add(state, action, reward, next_state, float(done))
            
            state = next_state
            episode_reward += reward
            
            # 训练
            agent.train(batch_size)
            
            if done:
                break
        
        rewards_history.append(episode_reward)
        print(f"Episode {episode}, Reward: {episode_reward}")
        
        # 保存模型
        if episode % save_every == 0:
            agent.save("td3_gridworld")
    
    return rewards_history

# %%
def check_trained_model_td3(env, agent, model_path, max_steps=1000):
    """
    交互式测试训练好的模型，动态添加障碍物来评估避障能力。

    :param env: 环境实例 (GridWorld)
    :param agent: 智能体实例
    :param model_path: 已训练好的模型文件路径
    :param max_steps: 每次测试的最大步数
    """
    # 加载训练好的模型
    agent.load_model(model_path)
    start_time = time.time()
    print(f"Loaded model from {model_path}")

    # 设置 epsilon 为 0（测试时只选择最优动作）
    agent.epsilon = 0

    # 初始化 Pygame
    pygame.init()
    grid_size = 10  # 每个格子的像素大小
    screen = pygame.display.set_mode((env.cols * grid_size, env.rows * grid_size))
    pygame.display.set_caption("Trained Model Test")
    clock = pygame.time.Clock()

    # 初始化字体
    pygame.font.init()
    font = pygame.font.SysFont("Arial", 24)

    # 测试
    state = env.reset()
    done = False
    total_reward = 0
    path = [env.agent_pos]  # 路径记录
    steps = 0

    while not done and steps < max_steps:
        # 渲染环境
        screen.fill((255, 255, 255))  # 清空屏幕，设置白色背景

        # 绘制栅格地图
        for i in range(env.rows):
            for j in range(env.cols):
                color = (255, 255, 255)  # 默认白色
                if env.grid_map[i, j] == 1:
                    color = (0, 0, 0)  # 黑色障碍物
                pygame.draw.rect(screen, color, (j * grid_size, i * grid_size, grid_size, grid_size))

        # 绘制目标
        pygame.draw.rect(
            screen,
            (0, 0, 255),
            (env.goal[1] * grid_size, env.goal[0] * grid_size, grid_size, grid_size)
        )  # 蓝色目标点

        # 绘制路径轨迹
        for pos in path:
            pygame.draw.rect(
                screen,
                (200, 200, 200),  # 浅灰色轨迹
                (int(pos[1] * grid_size), int(pos[0] * grid_size), grid_size, grid_size)  # 使用矩形表示路径
            )

        # 绘制智能体
        car_x = int(env.agent_pos[1] * grid_size + grid_size // 2)
        car_y = int(env.agent_pos[0] * grid_size + grid_size // 2)
        car_radius = grid_size // 4

        # 绘制小车的主体
        pygame.draw.circle(screen, (255, 0, 0), (car_x, car_y), car_radius)

        # 智能体选择动作
        action = agent.select_action(state)  # 测试时选择最优动作
        next_state, reward, done = env.step(action)

        pygame.display.flip()  # 更新显示

        # 更新状态和累计奖励
        state = next_state
        total_reward += reward
        path.append(env.agent_pos)  # 记录路径
        steps += 1

        # 检查是否按下退出事件或者添加障碍物
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                return
            elif event.type == pygame.MOUSEBUTTONDOWN:
                # 获取鼠标点击的坐标
                mouse_x, mouse_y = pygame.mouse.get_pos()
                # 转换为对应的栅格坐标
                grid_x = mouse_x // grid_size
                grid_y = mouse_y // grid_size
                # 在地图中添加障碍物
                if env.grid_map[grid_y, grid_x] == 0:  # 只在空白位置添加障碍物
                    env.grid_map[grid_y, grid_x] = 1
                    print(f"Obstacle added at ({grid_y}, {grid_x})")
        
        # 限制帧率
        clock.tick(0.7)
    end_time = time.time()
    pygame.quit()  # 测试完成后关闭窗口

    # 输出测试结果
    print(f"Test Completed. Total Reward: {total_reward}, Steps Taken: {steps}")
    print(f"仿真完成，耗时 {end_time - start_time:.2f} 秒")

# %%
def check_trained_model_num_td3(env, agent, model_path, max_steps=1000, num_runs=100):
    """
    测试训练好的 TD3 模型在 GridWorld 环境中的表现，统计成功次数。
    
    :param env: 环境实例 (GridWorld)
    :param agent: 智能体实例 (TD3)
    :param model_path: 已训练好的模型文件路径（不带扩展名）
    :param max_steps: 每次测试的最大步数
    :param num_runs: 测试的总次数
    """
    # 加载训练好的模型
    agent.load_model(model_path)
    print(f"Loaded model from {model_path}_actor.pth and {model_path}_critic.pth")
    
    success_count = 0  # 记录成功次数
    
    # 设置为评估模式
    agent.actor.eval()
    agent.critic.eval()
    
    with torch.no_grad():
        # 测试多次
        for run in range(1, num_runs + 1):
            state = env.reset()
            done = False
            steps = 0
            total_reward = 0
            path = [env.agent_pos.copy()]  # 路径记录
            
            while not done and steps < max_steps:
                # 智能体选择动作
                action = agent.select_action(state)
                next_state, reward, done = env.step(action)
                
                # 更新状态和累计奖励
                state = next_state
                total_reward += reward
                path.append(env.agent_pos.copy())  # 记录路径
                steps += 1
                
                # 检查是否到达目标
                if np.linalg.norm(env.agent_pos - np.array(env.goal)) < 0.5:
                    success_count += 1
                    break  # 达到目标则结束当前测试
            
            print(f"Run {run}: Reward = {total_reward}, Steps = {steps}, Success = {done and total_reward >= 10}")
    
    # 输出成功次数
    print(f"测试完成。成功次数: {success_count}/{num_runs}")

# %%
def train_main():
    # 设置 CUDA_LAUNCH_BLOCKING 以便同步错误报告（仅调试时使用）
    os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

    # 加载网格地图
    grid_map = np.loadtxt("grid_map_final.txt", dtype=int)
    
    # 定义目标点列表
    nodes = [(51, 12), (55, 23), (55, 30), (32, 47), (9, 50), (9, 64)]
    
    # 初始化环境
    env = GridWorld(
        grid_map=grid_map,
        start=(58, 5),
        goal=(51, 12),
        goal_list=nodes
    )
    
    state_dim = env.get_state().shape[0]  # 状态维度，例如 51
    action_dim = 2  # 连续动作：dx 和 dy
    max_action = 1.0  # 动作范围 [-1, 1]
    
    # 初始化 TD3 Agent
    agent = TD3(
        state_dim=state_dim,
        action_dim=action_dim,
        max_action=max_action,
    )
    
    # 开始训练
    print("Starting training...")
    train_td3(
        env=env,
        agent=agent,
        episodes=2000,
        max_steps=10000,
    )
    
    # 保存最终模型
    agent.save_model("td3_gridworld_final")

train_main()
# Out:
# Starting training...
# Episode 1, Reward: -19.454156605830832
# Episode 2, Reward: -26.67165886176781
# Episode 3, Reward: -18.00078806711348
# Episode 4, Reward: -30.84581672395841
# Episode 5, Reward: -24.218817535467444
# Episode 6, Reward: -20.53843797319585
# Episode 7, Reward: -9.353223146457182
# Episode 8, Reward: -14.234742097330182
# Episode 9, Reward: -12.91400888865037
# Episode 10, Reward: -12.850032421278112
# Episode 11, Reward: -15.651508267155567
# Episode 12, Reward: -20.0462168449548
# Episode 13, Reward: -19.066977694530358
# Episode 14, Reward: -15.304154476387994
# Episode 15, Reward: -14.263788723983284
# Episode 16, Reward: -21.433091954159853
# Episode 17, Reward: -25.20727133008628
# Episode 18, Reward: -16.674222510148077
# Episode 19, Reward: -21.528290816585763
# Episode 20, Reward: -19.01593214859142
# Episode 21, Reward: -18.027904546386004
# Episode 22, Reward: -18.057076455183605
# Episode 23, Reward: -20.474965214299033
# Episode 24, Reward: -19.41148338529437
# Episode 25, Reward: -14.229840614729024
# Episode 26, Reward: -18.331190624031176
# Episode 27, Reward: -21.79862188357035
# Episode 28, Reward: -21.489244475957967
# Episode 29, Reward: -21.873844822440297
# Episode 30, Reward: -21.52903040970913
# Episode 31, Reward: -16.992581344452663
# Episode 32, Reward: -5.449772608795781
# Episode 33, Reward: -3.0
# Episode 34, Reward: -5.437034986650816
# Episode 35, Reward: -5.443883174217566
# Episode 36, Reward: -5.446202689447844
# Episode 37, Reward: -5.45852006356276
# Episode 38, Reward: -3.0
# Episode 39, Reward: -3.0
# Episode 40, Reward: -5.466948367673968
# Episode 41, Reward: -5.479251943662463
# Episode 42, Reward: -5.471500940632966
# Episode 43, Reward: -5.461628385860973
# Episode 44, Reward: -3.0
# Episode 45, Reward: -5.455148195962301
# Episode 46, Reward: -3.0
# Episode 47, Reward: -3.0
# Episode 48, Reward: -3.0
# Episode 49, Reward: -3.0
# Episode 50, Reward: -5.4884783318876025
# Episode 51, Reward: -3.0
# Episode 52, Reward: -5.464921390344079
# Episode 53, Reward: -5.469482705548492
# Episode 54, Reward: -5.492317830030179
# Episode 55, Reward: -5.469465514590219
# Episode 56, Reward: -5.513155071749802
# Episode 57, Reward: -3.0
# Episode 58, Reward: -4.434558926667176
# Episode 59, Reward: -4.4354447936371235
# Episode 60, Reward: -4.4218480732695165
# Episode 61, Reward: -5.446556034988763
# Episode 62, Reward: -3.0
# Episode 63, Reward: -5.479620100209457
# Episode 64, Reward: -5.501932802853274
# Episode 65, Reward: -3.0
# Episode 66, Reward: -3.0
# Episode 67, Reward: -5.442142825584259
# Episode 68, Reward: -3.0
# Episode 69, Reward: -5.457107080821153
# Episode 70, Reward: -5.435837703822225
# Episode 71, Reward: -5.468469102572794
# Episode 72, Reward: -3.0
# Episode 73, Reward: -3.0
# Episode 74, Reward: -5.4810432440742725
# Episode 75, Reward: -3.0
# Episode 76, Reward: -5.494814500043232
# Episode 77, Reward: -3.0
# Episode 78, Reward: -3.0
# Episode 79, Reward: -5.452586395446698
# Episode 80, Reward: -3.0
# Episode 81, Reward: -3.0
# Episode 82, Reward: -5.470316880965327
# Episode 83, Reward: -3.0
# Episode 84, Reward: -5.4757637451408545
# Episode 85, Reward: -5.488063442780201
# Episode 86, Reward: -3.0
# Episode 87, Reward: -5.451688073169836
# Episode 88, Reward: -3.0
# Episode 89, Reward: -3.0
# Episode 90, Reward: -5.476089252927351
# Episode 91, Reward: -3.0
# Episode 92, Reward: -3.0
# Episode 93, Reward: -3.0
# Episode 94, Reward: -3.0
# Episode 95, Reward: -3.0
# Episode 96, Reward: -3.0
# Episode 97, Reward: -3.0
# Episode 98, Reward: -3.0
# Episode 99, Reward: -5.501502872630701
# Episode 100, Reward: -3.0
# Episode 101, Reward: -5.4796544342423115
# Episode 102, Reward: -3.0
# Episode 103, Reward: -5.470740943230247
# Episode 104, Reward: -3.0
# Episode 105, Reward: -5.472327156930188
# Episode 106, Reward: -3.0
# Episode 107, Reward: -3.0
# Episode 108, Reward: -5.4773226003877316
# Episode 109, Reward: -5.456207515488729
# Episode 110, Reward: -5.461700581125445
# Episode 111, Reward: -4.405496676383526
# Episode 112, Reward: -5.444879758046853
# Episode 113, Reward: -5.453687595954667
# Episode 114, Reward: -5.475813043798353
# Episode 115, Reward: -3.0
# Episode 116, Reward: -5.476903043127569
# Episode 117, Reward: -5.468196308811418
# Episode 118, Reward: -3.0
# Episode 119, Reward: -4.432846635355599
# Episode 120, Reward: -5.475736276519399
# Episode 121, Reward: -5.436697687226822
# Episode 122, Reward: -5.4698995365599625
# Episode 123, Reward: -3.0
# Episode 124, Reward: -5.463237883010516
# Episode 125, Reward: -3.0
# Episode 126, Reward: -5.478416906086107
# Episode 127, Reward: -3.0
# Episode 128, Reward: -3.0
# Episode 129, Reward: -3.0
# Episode 130, Reward: -3.0
# Episode 131, Reward: -5.479971195565851
# Episode 132, Reward: -3.0
# Episode 133, Reward: -3.0
# Episode 134, Reward: -5.479427201369859
# Episode 135, Reward: -3.0
# Episode 136, Reward: -5.441651387569891
# Episode 137, Reward: -3.0
# Episode 138, Reward: -5.46338572931109
# Episode 139, Reward: -5.457553262008913
# Episode 140, Reward: -5.460641461412319
# Episode 141, Reward: -5.4659905197988365
# Episode 142, Reward: -4.405686605524007
# Episode 143, Reward: -3.0
# Episode 144, Reward: -3.0
# Episode 145, Reward: -3.0
# Episode 146, Reward: -3.0
# Episode 147, Reward: -5.458871380561922
# Episode 148, Reward: -3.0
# Episode 149, Reward: -5.502983585749734
# Episode 150, Reward: -5.47632017165923
# Episode 151, Reward: -3.0
# Episode 152, Reward: -5.464913318486046
# Episode 153, Reward: -3.0
# Episode 154, Reward: -5.451099421589885
# Episode 155, Reward: -3.0
# Episode 156, Reward: -3.0
# Episode 157, Reward: -5.456092283680054
# Episode 158, Reward: -3.0
# Episode 159, Reward: -3.0
# Episode 160, Reward: -3.0
# Episode 161, Reward: -5.495557166653943
# Episode 162, Reward: -5.466979075012844
# Episode 163, Reward: -5.462904626150918
# Episode 164, Reward: -5.475943446334782
# Episode 165, Reward: -5.489721008434787
# Episode 166, Reward: -5.487814967809017
# Episode 167, Reward: -4.407560099305632
# Episode 168, Reward: -3.0
# Episode 169, Reward: -3.0
# Episode 170, Reward: -5.446678732991596
# Episode 171, Reward: -5.486046047063848
# Episode 172, Reward: -5.4616612794897925
# Episode 173, Reward: -3.0
# Episode 174, Reward: -5.45335374844265
# Episode 175, Reward: -5.447909905549514
# Episode 176, Reward: -3.0
# Episode 177, Reward: -3.0
# Episode 178, Reward: -3.0
# Episode 179, Reward: -5.43705981035719
# Episode 180, Reward: -3.0
# Episode 181, Reward: -3.0
# Episode 182, Reward: -5.4907400790491785
# Episode 183, Reward: -5.46207624411123
# Episode 184, Reward: -5.461470997904644
# Episode 185, Reward: -3.0
# Episode 186, Reward: -3.0
# Episode 187, Reward: -5.4497132028120205
# Episode 188, Reward: -3.0
# Episode 189, Reward: -3.0
# Episode 190, Reward: -3.0
# Episode 191, Reward: -3.0
# Episode 192, Reward: -3.0
# Episode 193, Reward: -4.408654541860354
# Episode 194, Reward: -4.380455769307519
# Episode 195, Reward: -4.399784612790489
# Episode 196, Reward: -5.487751657753064
# Episode 197, Reward: -5.472846202531386
# Episode 198, Reward: -3.0
# Episode 199, Reward: -5.474848361272425
# Episode 200, Reward: -3.0
# Episode 201, Reward: -3.0
# Episode 202, Reward: -5.45149514096553
# Episode 203, Reward: -5.461402738414985
# Episode 204, Reward: -5.454210483095336
# Episode 205, Reward: -5.461407619751273
# Episode 206, Reward: -5.462885185523166
# Episode 207, Reward: -3.0
# Episode 208, Reward: -5.47913633093995
# Episode 209, Reward: -3.0
# Episode 210, Reward: -5.444170027903663
# Episode 211, Reward: -3.0
# Episode 212, Reward: -3.0
# Episode 213, Reward: -3.0
# Episode 214, Reward: -5.448160138722404
# Episode 215, Reward: -5.495305345581639
# Episode 216, Reward: -4.427306813601199
# Episode 217, Reward: -3.0
# Episode 218, Reward: -5.458910823087481
# Episode 219, Reward: -5.471987452740462
# Episode 220, Reward: -3.0
# Episode 221, Reward: -5.484221719791226
# Episode 222, Reward: -5.491901351262175
# Episode 223, Reward: -3.0
# Episode 224, Reward: -5.4630091012176685
# Episode 225, Reward: -3.0
# Episode 226, Reward: -3.0
# Episode 227, Reward: -3.0
# Episode 228, Reward: -3.0
# Episode 229, Reward: -3.0
# Episode 230, Reward: -5.484562369860554
# Episode 231, Reward: -4.431326736201395
# Episode 232, Reward: -4.428007179319799
# Episode 233, Reward: -5.470741751295123
# Episode 234, Reward: -5.479372041222265
# Episode 235, Reward: -5.456201407783832
# Episode 236, Reward: -5.483312911485675
# Episode 237, Reward: -5.44935515376333
# Episode 238, Reward: -3.0
# Episode 239, Reward: -5.463957644569117
# Episode 240, Reward: -5.46804150202205
# Episode 241, Reward: -5.4815520271750104
# Episode 242, Reward: -3.0
# Episode 243, Reward: -3.0
# Episode 244, Reward: -3.0
# Episode 245, Reward: -5.464263882556281
# Episode 246, Reward: -5.467758601965803
# Episode 247, Reward: -3.0
# Episode 248, Reward: -5.445677747352217
# Episode 249, Reward: -5.485812932940363
# Episode 250, Reward: -5.464638014185191
# Episode 251, Reward: -3.0
# Episode 252, Reward: -3.0
# Episode 253, Reward: -5.4832117451308084
# Episode 254, Reward: -5.450131378687162
# Episode 255, Reward: -5.467206798969378
# Episode 256, Reward: -5.476175746088895
# Episode 257, Reward: -3.0
# Episode 258, Reward: -5.46756170395691
# Episode 259, Reward: -3.0
# Episode 260, Reward: -3.0
# Episode 261, Reward: -4.4243915649464185
# Episode 262, Reward: -3.0
# Episode 263, Reward: -5.465790810308975
# Episode 264, Reward: -5.457806995670281
# Episode 265, Reward: -3.0
# Episode 266, Reward: -3.0
# Episode 267, Reward: -5.475213892834025
# Episode 268, Reward: -5.455857695936747
# Episode 269, Reward: -5.447007990836343
# Episode 270, Reward: -5.438070069438651
# Episode 271, Reward: -3.0
# Episode 272, Reward: -4.432934712270493
# Episode 273, Reward: -3.0
# Episode 274, Reward: -5.464660828439474
# Episode 275, Reward: -5.478949093933651
# Episode 276, Reward: -3.0
# Episode 277, Reward: -5.4663666065754715
# Episode 278, Reward: -5.46602998505483
# Episode 279, Reward: -5.445430814736375
# Episode 280, Reward: -5.461498263719005
# Episode 281, Reward: -3.0
# Episode 282, Reward: -5.444121491902077
# Episode 283, Reward: -3.0
# Episode 284, Reward: -3.0
# Episode 285, Reward: -5.472513916526006
# Episode 286, Reward: -5.452033918605745
# Episode 287, Reward: -3.0
# Episode 288, Reward: -3.0
# Episode 289, Reward: -3.0
# Episode 290, Reward: -3.0
# Episode 291, Reward: -3.0
# Episode 292, Reward: -3.0
# Episode 293, Reward: -5.442261316393944
# Episode 294, Reward: -3.0
# Episode 295, Reward: -5.444533679566021
# Episode 296, Reward: -5.4534584698135244
# Episode 297, Reward: -5.466756663197264
# Episode 298, Reward: -5.46472682963987
# Episode 299, Reward: -5.483101641693449
# Episode 300, Reward: -4.399079572997193
# Episode 301, Reward: -3.0
# Episode 302, Reward: -5.436967091720886
# Episode 303, Reward: -4.430273466045362
# Episode 304, Reward: -5.4800357489227345
# Episode 305, Reward: -3.0
# Episode 306, Reward: -5.440669741646266
# Episode 307, Reward: -5.470416515696355
# Episode 308, Reward: -5.489042137807664
# Episode 309, Reward: -5.457898649019177
# Episode 310, Reward: -5.462329419397569
# Episode 311, Reward: -5.473431833882687
# Episode 312, Reward: -3.0
# Episode 313, Reward: -3.0
# Episode 314, Reward: -3.0
# Episode 315, Reward: -3.0
# Episode 316, Reward: -3.0
# Episode 317, Reward: -5.459971709155123
# Episode 318, Reward: -5.437659015056694
# Episode 319, Reward: -5.486552175385017
# Episode 320, Reward: -3.0
# Episode 321, Reward: -3.0
# Episode 322, Reward: -3.0
# Episode 323, Reward: -3.0
# Episode 324, Reward: -5.489248720434621
# Episode 325, Reward: -3.0
# Episode 326, Reward: -3.0
# Episode 327, Reward: -3.0
# Episode 328, Reward: -4.425510647578631
# Episode 329, Reward: -3.0
# Episode 330, Reward: -3.0
# Episode 331, Reward: -3.0
# Episode 332, Reward: -3.0
# Episode 333, Reward: -5.440803658311914
# Episode 334, Reward: -3.0
# Episode 335, Reward: -5.468617149340064
# Episode 336, Reward: -3.0
# Episode 337, Reward: -3.0
# Episode 338, Reward: -3.0
# Episode 339, Reward: -5.455636108844363
# Episode 340, Reward: -3.0
# Episode 341, Reward: -5.497494452383043
# Episode 342, Reward: -3.0
# Episode 343, Reward: -5.462862595960188
# Episode 344, Reward: -3.0
# Episode 345, Reward: -5.468098271378403
# Episode 346, Reward: -3.0
# Episode 347, Reward: -5.517973110533263
# Episode 348, Reward: -5.4791974762606825
# Episode 349, Reward: -3.0
# Episode 350, Reward: -3.0
# Episode 351, Reward: -3.0
# Episode 352, Reward: -5.456745704430277
# Episode 353, Reward: -5.470098401698717
# Episode 354, Reward: -5.440390985793707
# Episode 355, Reward: -3.0
# Episode 356, Reward: -3.0
# Episode 357, Reward: -3.0
# Episode 358, Reward: -5.454512501325652
# Episode 359, Reward: -3.0
# Episode 360, Reward: -3.0
# Episode 361, Reward: -3.0
# Episode 362, Reward: -3.0
# Episode 363, Reward: -5.460853099592317
# Episode 364, Reward: -3.0
# Episode 365, Reward: -3.0
# Episode 366, Reward: -3.0
# Episode 367, Reward: -3.0
# Episode 368, Reward: -3.0
# Episode 369, Reward: -5.485472257685889
# Episode 370, Reward: -3.0
# Episode 371, Reward: -5.453672398682519
# Episode 372, Reward: -3.0
# Episode 373, Reward: -5.4425313623287614
# Episode 374, Reward: -3.0
# Episode 375, Reward: -5.455183882607553
# Episode 376, Reward: -5.4640895242530165
# Episode 377, Reward: -5.471886782485704
# Episode 378, Reward: -3.0
# Episode 379, Reward: -3.0
# Episode 380, Reward: -5.466028010763141
# Episode 381, Reward: -3.0
# Episode 382, Reward: -3.0
# Episode 383, Reward: -3.0
# Episode 384, Reward: -5.495881464264084
# Episode 385, Reward: -5.470123437735334
# Episode 386, Reward: -3.0
# Episode 387, Reward: -3.0
# Episode 388, Reward: -5.4517472722666875
# Episode 389, Reward: -5.474630933650912
# Episode 390, Reward: -5.443363506197117
# Episode 391, Reward: -3.0
# Episode 392, Reward: -5.459521337411458
# Episode 393, Reward: -5.453422056789659
# Episode 394, Reward: -3.0
# Episode 395, Reward: -5.466893735532038
# Episode 396, Reward: -3.0
# Episode 397, Reward: -3.0
# Episode 398, Reward: -4.409846790527107
# Episode 399, Reward: -5.443548866104612
# Episode 400, Reward: -3.0
# Episode 401, Reward: -3.0
# Episode 402, Reward: -5.457944806164756
# Episode 403, Reward: -3.0
# Episode 404, Reward: -5.494312133763517
# Episode 405, Reward: -4.3866678646173884
# Episode 406, Reward: -3.0
# Episode 407, Reward: -3.0
# Episode 408, Reward: -5.4886791553480485
# Episode 409, Reward: -5.445243614374835
# Episode 410, Reward: -3.0
# Episode 411, Reward: -3.0
# Episode 412, Reward: -3.0
# Episode 413, Reward: -3.0
# Episode 414, Reward: -3.0
# Episode 415, Reward: -3.0
# Episode 416, Reward: -3.0
# Episode 417, Reward: -3.0
# Episode 418, Reward: -4.40930719461446
# Episode 419, Reward: -5.441801662394898
# Episode 420, Reward: -3.0
# Episode 421, Reward: -3.0
# Episode 422, Reward: -3.0
# Episode 423, Reward: -3.0
# Episode 424, Reward: -3.0
# Episode 425, Reward: -5.474892052108151
# Episode 426, Reward: -3.0
# Episode 427, Reward: -5.436210255177194
# Episode 428, Reward: -3.0
# Episode 429, Reward: -5.454445329656588
# Episode 430, Reward: -3.0
# Episode 431, Reward: -3.0
# Episode 432, Reward: -5.472360343458814
# Episode 433, Reward: -5.44228449543302
# Episode 434, Reward: -4.414886010384801
# Episode 435, Reward: -5.447844373808062
# Episode 436, Reward: -3.0
# Episode 437, Reward: -3.0
# Episode 438, Reward: -3.0
# Episode 439, Reward: -3.0
# Episode 440, Reward: -5.445794419029888
# Episode 441, Reward: -5.462303582142043
# Episode 442, Reward: -3.0
# Episode 443, Reward: -5.48308793058931
# Episode 444, Reward: -5.458553774328575
# Episode 445, Reward: -3.0
# Episode 446, Reward: -3.0
# Episode 447, Reward: -3.0
# Episode 448, Reward: -3.0
# Episode 449, Reward: -5.503871977841536
# Episode 450, Reward: -3.0
# Episode 451, Reward: -3.0
# Episode 452, Reward: -3.0
# Episode 453, Reward: -4.416695705530544
# Episode 454, Reward: -3.0
# Episode 455, Reward: -3.0
# Episode 456, Reward: -3.0
# Episode 457, Reward: -3.0
# Episode 458, Reward: -5.464377962791234
# Episode 459, Reward: -3.0
# Episode 460, Reward: -5.472767972856635
# Episode 461, Reward: -3.0
# Episode 462, Reward: -4.419448717036166
# Episode 463, Reward: -5.44171292975493
# Episode 464, Reward: -5.506662701545803
# Episode 465, Reward: -3.0
# Episode 466, Reward: -3.0
# Episode 467, Reward: -5.460397727921416
# Episode 468, Reward: -3.0
# Episode 469, Reward: -3.0
# Episode 470, Reward: -3.0
# Episode 471, Reward: -5.474347862724344
# Episode 472, Reward: -3.0
# Episode 473, Reward: -3.0
# Episode 474, Reward: -5.476002004020551
# Episode 475, Reward: -3.0
# Episode 476, Reward: -3.0
# Episode 477, Reward: -4.426576467181169
# Episode 478, Reward: -5.447040608181056
# Episode 479, Reward: -3.0
# Episode 480, Reward: -3.0
# Episode 481, Reward: -3.0
# Episode 482, Reward: -3.0
# Episode 483, Reward: -3.0
# Episode 484, Reward: -3.0
# Episode 485, Reward: -5.48049147954283
# Episode 486, Reward: -4.43188404772427
# Episode 487, Reward: -3.0
# Episode 488, Reward: -3.0
# Episode 489, Reward: -5.455789235029542
# Episode 490, Reward: -4.431307870319585
# Episode 491, Reward: -4.405734265650475
# Episode 492, Reward: -3.0
# Episode 493, Reward: -5.466892827896869
# Episode 494, Reward: -3.0
# Episode 495, Reward: -5.448140128515278
# Episode 496, Reward: -5.473569314785352
# Episode 497, Reward: -5.440723630014342
# Episode 498, Reward: -3.0
# Episode 499, Reward: -5.456384147452501
# Episode 500, Reward: -3.0
# Episode 501, Reward: -3.0
# Episode 502, Reward: -3.0
# Episode 503, Reward: -5.479770804486371
# Episode 504, Reward: -3.0
# Episode 505, Reward: -3.0
# Episode 506, Reward: -3.0
# Episode 507, Reward: -3.0
# Episode 508, Reward: -5.47074968294529
# Episode 509, Reward: -5.452375403131604
# Episode 510, Reward: -3.0
# Episode 511, Reward: -5.4788027646492505
# Episode 512, Reward: -5.450331934208245
# Episode 513, Reward: -4.414662972777165
# Episode 514, Reward: -5.4772575893397395
# Episode 515, Reward: -3.0
# Episode 516, Reward: -3.0
# Episode 517, Reward: -3.0
# Episode 518, Reward: -3.0
# Episode 519, Reward: -3.0
# Episode 520, Reward: -3.0
# Episode 521, Reward: -5.481829158250208
# Episode 522, Reward: -5.47051136536941
# Episode 523, Reward: -5.483757824952815
# Episode 524, Reward: -3.0
# Episode 525, Reward: -5.47177349915061
# Episode 526, Reward: -3.0
# Episode 527, Reward: -5.4661764814310985
# Episode 528, Reward: -5.461808965587323
# Episode 529, Reward: -3.0
# Episode 530, Reward: -5.485702133718605
# Episode 531, Reward: -3.0
# Episode 532, Reward: -5.433913234581643
# Episode 533, Reward: -3.0
# Episode 534, Reward: -5.471537572952489
# Episode 535, Reward: -3.0
# Episode 536, Reward: -5.468389693840246
# Episode 537, Reward: -3.0
# Episode 538, Reward: -5.475801518906304
# Episode 539, Reward: -5.470304809162249
# Episode 540, Reward: -3.0
# Episode 541, Reward: -3.0
# Episode 542, Reward: -5.478234522316918
# Episode 543, Reward: -3.0
# Episode 544, Reward: -3.0
# Episode 545, Reward: -3.0
# Episode 546, Reward: -5.467441069916801
# Episode 547, Reward: -5.479231321036815
# Episode 548, Reward: -3.0
# Episode 549, Reward: -3.0
# Episode 550, Reward: -3.0
# Episode 551, Reward: -4.431440515320837
# Episode 552, Reward: -3.0
# Episode 553, Reward: -3.0
# Episode 554, Reward: -3.0
# Episode 555, Reward: -3.0
# Episode 556, Reward: -3.0
# Episode 557, Reward: -3.0
# Episode 558, Reward: -3.0
# Episode 559, Reward: -3.0
# Episode 560, Reward: -3.0
# Episode 561, Reward: -3.0
# Episode 562, Reward: -5.472295006240389
# Episode 563, Reward: -3.0
# Episode 564, Reward: -3.0
# Episode 565, Reward: -5.479361271891972
# Episode 566, Reward: -3.0
# Episode 567, Reward: -3.0
# Episode 568, Reward: -3.0
# Episode 569, Reward: -5.475563887719023
# Episode 570, Reward: -3.0
# Episode 571, Reward: -3.0
# Episode 572, Reward: -4.433686956685629
# Episode 573, Reward: -3.0
# Episode 574, Reward: -3.0
# Episode 575, Reward: -5.473412294495374
# Episode 576, Reward: -5.479619307797975
# Episode 577, Reward: -5.456925923583867
# Episode 578, Reward: -4.422381363165257
# Episode 579, Reward: -5.443458888166164
# Episode 580, Reward: -4.43036887486031
# Episode 581, Reward: -3.0
# Episode 582, Reward: -5.476146563575595
# Episode 583, Reward: -5.446053917831364
# Episode 584, Reward: -5.438689624613742
# Episode 585, Reward: -3.0
# Episode 586, Reward: -3.0
# Episode 587, Reward: -3.0
# Episode 588, Reward: -5.454456970577834
# Episode 589, Reward: -5.4915389827658
# Episode 590, Reward: -3.0
# Episode 591, Reward: -5.460413143535332
# Episode 592, Reward: -4.429913115659446
# Episode 593, Reward: -5.461878598183107
# Episode 594, Reward: -3.0
# Episode 595, Reward: -3.0
# Episode 596, Reward: -5.497658681605464
# Episode 597, Reward: -5.4475896257042224
# Episode 598, Reward: -5.478841008442105
# Episode 599, Reward: -3.0
# Episode 600, Reward: -3.0
# Episode 601, Reward: -3.0
# Episode 602, Reward: -3.0
# Episode 603, Reward: -5.452595553277348
# Episode 604, Reward: -5.474741478939337
# Episode 605, Reward: -3.0
# Episode 606, Reward: -3.0
# Episode 607, Reward: -5.436892888161709
# Episode 608, Reward: -3.0
# Episode 609, Reward: -3.0
# Episode 610, Reward: -3.0
# Episode 611, Reward: -3.0
# Episode 612, Reward: -3.0
# Episode 613, Reward: -4.42813414817516
# Episode 614, Reward: -4.400555153000433
# Episode 615, Reward: -5.479933441605022
# Episode 616, Reward: -3.0
# Episode 617, Reward: -5.490579615049579
# Episode 618, Reward: -5.479966914840972
# Episode 619, Reward: -3.0
# Episode 620, Reward: -5.475954557007778
# Episode 621, Reward: -3.0
# Episode 622, Reward: -3.0
# Episode 623, Reward: -5.439822942079627
# Episode 624, Reward: -5.444520747653265
# Episode 625, Reward: -3.0
# Episode 626, Reward: -3.0
# Episode 627, Reward: -4.429355267345262
# Episode 628, Reward: -3.0
# Episode 629, Reward: -5.49205815430277
# Episode 630, Reward: -5.474422030571974
# Episode 631, Reward: -3.0
# Episode 632, Reward: -5.477383380620832
# Episode 633, Reward: -4.3981074340021316
# Episode 634, Reward: -3.0
# Episode 635, Reward: -3.0
# Episode 636, Reward: -3.0
# Episode 637, Reward: -3.0
# Episode 638, Reward: -5.479311459210794
# Episode 639, Reward: -5.461859971072315
# Episode 640, Reward: -5.486097921799306
# Episode 641, Reward: -3.0
# Episode 642, Reward: -3.0
# Episode 643, Reward: -3.0
# Episode 644, Reward: -5.436182563377851
# Episode 645, Reward: -3.0
# Episode 646, Reward: -5.473992594808227
# Episode 647, Reward: -3.0
# Episode 648, Reward: -3.0
# Episode 649, Reward: -3.0
# Episode 650, Reward: -5.494147078496431
# Episode 651, Reward: -4.414051155604659
# Episode 652, Reward: -3.0
# Episode 653, Reward: -5.479957454584153
# Episode 654, Reward: -3.0
# Episode 655, Reward: -5.469980855982165
# Episode 656, Reward: -5.451336704812839
# Episode 657, Reward: -4.398845375418848
# Episode 658, Reward: -3.0
# Episode 659, Reward: -4.422772033231874
# Episode 660, Reward: -5.498803822954361
# Episode 661, Reward: -3.0
# Episode 662, Reward: -5.460195356076444
# Episode 663, Reward: -3.0
# Episode 664, Reward: -3.0
# Episode 665, Reward: -5.447144627781542
# Episode 666, Reward: -3.0
# Episode 667, Reward: -5.457724022830504
# Episode 668, Reward: -3.0
# Episode 669, Reward: -4.413813274980269
# Episode 670, Reward: -4.434611124106753
# Episode 671, Reward: -3.0
# Episode 672, Reward: -5.478197513816319
# Episode 673, Reward: -3.0
# Episode 674, Reward: -3.0
# Episode 675, Reward: -5.464930731005957
# Episode 676, Reward: -3.0
# Episode 677, Reward: -3.0
# Episode 678, Reward: -3.0
# Episode 679, Reward: -5.47579956914824
# Episode 680, Reward: -5.464903056698296
# Episode 681, Reward: -5.4571510750171415
# Episode 682, Reward: -3.0
# Episode 683, Reward: -5.454439916534435
# Episode 684, Reward: -3.0
# Episode 685, Reward: -5.445819780073851
# Episode 686, Reward: -3.0
# Episode 687, Reward: -3.0
# Episode 688, Reward: -3.0
# Episode 689, Reward: -4.42772273056468
# Episode 690, Reward: -5.441338541412748
# Episode 691, Reward: -5.470526814730834
# Episode 692, Reward: -5.482910237828621
# Episode 693, Reward: -4.430897129302666
# Episode 694, Reward: -3.0
# Episode 695, Reward: -3.0
# Episode 696, Reward: -5.457432008146144
# Episode 697, Reward: -3.0
# Episode 698, Reward: -3.0
# Episode 699, Reward: -3.0
# Episode 700, Reward: -3.0
# Episode 701, Reward: -3.0
# Episode 702, Reward: -5.472407711721967
# Episode 703, Reward: -5.445721084732361
# Episode 704, Reward: -3.0
# Episode 705, Reward: -3.0
# Episode 706, Reward: -3.0
# Episode 707, Reward: -5.450639514054023
# Episode 708, Reward: -5.452024412739162
# Episode 709, Reward: -5.458982130046124
# Episode 710, Reward: -3.0
# Episode 711, Reward: -3.0
# Episode 712, Reward: -3.0
# Episode 713, Reward: -3.0
# Episode 714, Reward: -3.0
# Episode 715, Reward: -5.466473640959583
# Episode 716, Reward: -4.390157665716454
# Episode 717, Reward: -3.0
# Episode 718, Reward: -3.0
# Episode 719, Reward: -3.0
# Episode 720, Reward: -5.453283150420499
# Episode 721, Reward: -3.0
# Episode 722, Reward: -5.515606763013485
# Episode 723, Reward: -5.4686721535441105
# Episode 724, Reward: -3.0
# Episode 725, Reward: -3.0
# Episode 726, Reward: -3.0
# Episode 727, Reward: -3.0
# Episode 728, Reward: -5.46369369013371
# Episode 729, Reward: -5.462083187484467
# Episode 730, Reward: -3.0
# Episode 731, Reward: -5.444921266867608
# Episode 732, Reward: -5.4712196434174185
# Episode 733, Reward: -5.457017857069096
# Episode 734, Reward: -5.520337158921972
# Episode 735, Reward: -5.457510456694624
# Episode 736, Reward: -3.0
# Episode 737, Reward: -5.464724924036718
# Episode 738, Reward: -3.0
# Episode 739, Reward: -3.0
# Episode 740, Reward: -4.3944673605763445
# Episode 741, Reward: -5.498983223811823
# Episode 742, Reward: -5.457627665549952
# Episode 743, Reward: -4.382187060838941
# Episode 744, Reward: -5.466060413311624
# Episode 745, Reward: -3.0
# Episode 746, Reward: -3.0
# Episode 747, Reward: -3.0
# Episode 748, Reward: -3.0
# Episode 749, Reward: -5.479449010191464
# Episode 750, Reward: -5.485766015472495
# Episode 751, Reward: -5.464790022787389
# Episode 752, Reward: -3.0
# Episode 753, Reward: -3.0
# Episode 754, Reward: -3.0
# Episode 755, Reward: -3.0
# Episode 756, Reward: -3.0
# Episode 757, Reward: -5.445277748273762
# Episode 758, Reward: -5.4656649957798535
# Episode 759, Reward: -4.42224767771431
# Episode 760, Reward: -5.452560413828973
# Episode 761, Reward: -3.0
# Episode 762, Reward: -5.497891585536115
# Episode 763, Reward: -3.0
# Episode 764, Reward: -4.399386712855957
# Episode 765, Reward: -5.467723243592676
# Episode 766, Reward: -4.411006498257262
# Episode 767, Reward: -5.460460342325669
# Episode 768, Reward: -5.435959946299969
# Episode 769, Reward: -3.0
# Episode 770, Reward: -5.501054379974119
# Episode 771, Reward: -5.47136030063499
# Episode 772, Reward: -5.469659555285091
# Episode 773, Reward: -3.0
# Episode 774, Reward: -4.420137297641388
# Episode 775, Reward: -3.0
# Episode 776, Reward: -3.0
# Episode 777, Reward: -3.0
# Episode 778, Reward: -3.0
# Episode 779, Reward: -5.470010039289827
# Episode 780, Reward: -3.0
# Episode 781, Reward: -3.0
# Episode 782, Reward: -5.437165331495104
# Episode 783, Reward: -3.0
# Episode 784, Reward: -5.467798827608961
# Episode 785, Reward: -4.426560535851527
# Episode 786, Reward: -5.4826669707305875
# Episode 787, Reward: -3.0
# Episode 788, Reward: -5.489883733313518
# Episode 789, Reward: -5.461903442276705
# Episode 790, Reward: -3.0
# Episode 791, Reward: -5.459846225558165
# Episode 792, Reward: -5.466525458649919
# Episode 793, Reward: -3.0
# Episode 794, Reward: -5.475145390661932
# Episode 795, Reward: -3.0
# Episode 796, Reward: -3.0
# Episode 797, Reward: -5.436080029812192
# Episode 798, Reward: -3.0
# Episode 799, Reward: -5.503580862423036
# Episode 800, Reward: -5.452384984053127
# Episode 801, Reward: -3.0
# Episode 802, Reward: -3.0
# Episode 803, Reward: -5.45430328813815
# Episode 804, Reward: -5.437289194504615
# Episode 805, Reward: -3.0
# Episode 806, Reward: -3.0
# Episode 807, Reward: -3.0
# Episode 808, Reward: -3.0
# Episode 809, Reward: -3.0
# Episode 810, Reward: -3.0
# Episode 811, Reward: -3.0
# Episode 812, Reward: -3.0
# Episode 813, Reward: -3.0
# Episode 814, Reward: -3.0
# Episode 815, Reward: -3.0
# Episode 816, Reward: -5.43911151724156
# Episode 817, Reward: -5.484021773693552
# Episode 818, Reward: -3.0
# Episode 819, Reward: -5.485617585611483
# Episode 820, Reward: -5.470789509811066
# Episode 821, Reward: -5.476181000453656
# Episode 822, Reward: -5.4476699957697585
# Episode 823, Reward: -5.477017135057615
# Episode 824, Reward: -3.0
# Episode 825, Reward: -3.0
# Episode 826, Reward: -5.492994496411574
# Episode 827, Reward: -5.467033469528957
# Episode 828, Reward: -3.0
# Episode 829, Reward: -3.0
# Episode 830, Reward: -5.436249312069106
# Episode 831, Reward: -5.509772439684319
# Episode 832, Reward: -3.0
# Episode 833, Reward: -5.469421988233025
# Episode 834, Reward: -5.435697971153672
# Episode 835, Reward: -3.0
# Episode 836, Reward: -5.443329562702227
# Episode 837, Reward: -5.464453110070142
# Episode 838, Reward: -3.0
# Episode 839, Reward: -3.0
# Episode 840, Reward: -3.0
# Episode 841, Reward: -3.0
# Episode 842, Reward: -4.401067679603759
# Episode 843, Reward: -4.368407638982444
# Episode 844, Reward: -5.44891303134869
# Episode 845, Reward: -3.0
# Episode 846, Reward: -3.0
# Episode 847, Reward: -5.488898661392051
# Episode 848, Reward: -4.426480083703586
# Episode 849, Reward: -5.445656121797738
# Episode 850, Reward: -5.473145703385889
# Episode 851, Reward: -5.506536181330619
# Episode 852, Reward: -3.0
# Episode 853, Reward: -3.0
# Episode 854, Reward: -3.0
# Episode 855, Reward: -5.475996548167054
# Episode 856, Reward: -5.475576692996967
# Episode 857, Reward: -3.0
# Episode 858, Reward: -3.0
# Episode 859, Reward: -5.476777228571862
# Episode 860, Reward: -5.473810492066442
# Episode 861, Reward: -5.464807185653026
# Episode 862, Reward: -5.4481570037458615
# Episode 863, Reward: -5.491819358859703
# Episode 864, Reward: -3.0
# Episode 865, Reward: -3.0
# Episode 866, Reward: -5.437503246213705
# Episode 867, Reward: -3.0
# Episode 868, Reward: -5.500493237377783
# Episode 869, Reward: -3.0
# Episode 870, Reward: -3.0
# Episode 871, Reward: -3.0
# Episode 872, Reward: -5.434462981469235
# Episode 873, Reward: -3.0
# Episode 874, Reward: -3.0
# Episode 875, Reward: -5.469283398339643
# Episode 876, Reward: -5.484043857318234
# Episode 877, Reward: -3.0
# Episode 878, Reward: -5.457896401992828
# Episode 879, Reward: -5.467407227144942
# Episode 880, Reward: -3.0
# Episode 881, Reward: -4.430361086695858
# Episode 882, Reward: -3.0
# Episode 883, Reward: -5.4658746276741095
# Episode 884, Reward: -5.4678152970663545
# Episode 885, Reward: -4.4300619867883055
# Episode 886, Reward: -3.0
# Episode 887, Reward: -5.474785819982127
# Episode 888, Reward: -3.0
# Episode 889, Reward: -3.0
# Episode 890, Reward: -3.0
# Episode 891, Reward: -5.441805987874491
# Episode 892, Reward: -4.417258967261892
# Episode 893, Reward: -4.411992108455029
# Episode 894, Reward: -5.468341409229181
# Episode 895, Reward: -3.0
# Episode 896, Reward: -3.0
# Episode 897, Reward: -5.476079496038876
# Episode 898, Reward: -3.0
# Episode 899, Reward: -3.0
# Episode 900, Reward: -3.0
# Episode 901, Reward: -5.4363790041222355
# Episode 902, Reward: -5.496562163630453
# Episode 903, Reward: -3.0
# Episode 904, Reward: -3.0
# Episode 905, Reward: -5.437067716925803
# Episode 906, Reward: -5.4775547797999256
# Episode 907, Reward: -3.0
# Episode 908, Reward: -3.0
# Episode 909, Reward: -3.0
# Episode 910, Reward: -5.513224307298764
# Episode 911, Reward: -3.0
# Episode 912, Reward: -3.0
# Episode 913, Reward: -3.0
# Episode 914, Reward: -5.480706848175465
# Episode 915, Reward: -3.0
# Episode 916, Reward: -4.435350925107554
# Episode 917, Reward: -5.472523892936169
# Episode 918, Reward: -4.421391151071784
# Episode 919, Reward: -3.0
# Episode 920, Reward: -5.4626986985353
# Episode 921, Reward: -5.482973289814533
# Episode 922, Reward: -5.448761051220485
# Episode 923, Reward: -3.0
# Episode 924, Reward: -5.472167766114707
# Episode 925, Reward: -5.518671890000662
# Episode 926, Reward: -3.0
# Episode 927, Reward: -3.0
# Episode 928, Reward: -5.444198145078428
# Episode 929, Reward: -3.0
# Episode 930, Reward: -5.460181176341505
# Episode 931, Reward: -3.0
# Episode 932, Reward: -3.0
# Episode 933, Reward: -5.4683208805299985
# Episode 934, Reward: -4.429587429503804
# Episode 935, Reward: -3.0
# Episode 936, Reward: -4.424246377768656
# Episode 937, Reward: -3.0
# Episode 938, Reward: -5.444865476036961
# Episode 939, Reward: -3.0
# Episode 940, Reward: -3.0
# Episode 941, Reward: -5.453257575665822
# Episode 942, Reward: -3.0
# Episode 943, Reward: -5.505618515647841
# Episode 944, Reward: -5.48496156065765
# Episode 945, Reward: -3.0
# Episode 946, Reward: -3.0
# Episode 947, Reward: -3.0
# Episode 948, Reward: -3.0
# Episode 949, Reward: -5.453852948894042
# Episode 950, Reward: -5.477837011864352
# Episode 951, Reward: -5.464378226812163
# Episode 952, Reward: -3.0
# Episode 953, Reward: -5.465677795148646
# Episode 954, Reward: -3.0
# Episode 955, Reward: -3.0
# Episode 956, Reward: -5.461544831180438
# Episode 957, Reward: -5.4652399924975015
# Episode 958, Reward: -3.0
# Episode 959, Reward: -3.0
# Episode 960, Reward: -5.467025193673805
# Episode 961, Reward: -5.453865421412596
# Episode 962, Reward: -3.0
# Episode 963, Reward: -5.442206485534915
# Episode 964, Reward: -3.0
# Episode 965, Reward: -5.45779047298223
# Episode 966, Reward: -3.0
# Episode 967, Reward: -5.45467369635031
# Episode 968, Reward: -3.0
# Episode 969, Reward: -5.47338121478748
# Episode 970, Reward: -3.0
# Episode 971, Reward: -5.478495473944065
# Episode 972, Reward: -3.0
# Episode 973, Reward: -3.0
# Episode 974, Reward: -3.0
# Episode 975, Reward: -3.0
# Episode 976, Reward: -5.465179357984816
# Episode 977, Reward: -3.0
# Episode 978, Reward: -3.0
# Episode 979, Reward: -5.474079986301488
# Episode 980, Reward: -3.0
# Episode 981, Reward: -5.515823777785943
# Episode 982, Reward: -5.467905817973678
# Episode 983, Reward: -3.0
# Episode 984, Reward: -3.0
# Episode 985, Reward: -3.0
# Episode 986, Reward: -5.442742227409136
# Episode 987, Reward: -3.0
# Episode 988, Reward: -5.441154892658062
# Episode 989, Reward: -5.438332291962601
# Episode 990, Reward: -3.0
# Episode 991, Reward: -5.493705596913436
# Episode 992, Reward: -3.0
# Episode 993, Reward: -3.0
# Episode 994, Reward: -3.0
# Episode 995, Reward: -5.470227957038336
# Episode 996, Reward: -5.472833692328354
# Episode 997, Reward: -5.464832137115545
# Episode 998, Reward: -3.0
# Episode 999, Reward: -5.4762912850944065
# Episode 1000, Reward: -4.423459566554172
# Episode 1001, Reward: -5.484657686209946
# Episode 1002, Reward: -3.0
# Episode 1003, Reward: -5.471400458004366
# Episode 1004, Reward: -5.458395680693368
# Episode 1005, Reward: -3.0
# Episode 1006, Reward: -3.0
# Episode 1007, Reward: -5.444786695792866
# Episode 1008, Reward: -5.483435743769155
# Episode 1009, Reward: -4.4177584804916705
# Episode 1010, Reward: -3.0
# Episode 1011, Reward: -3.0
# Episode 1012, Reward: -3.0
# Episode 1013, Reward: -3.0
# Episode 1014, Reward: -4.386956094312488
# Episode 1015, Reward: -3.0
# Episode 1016, Reward: -3.0
# Episode 1017, Reward: -5.4836290817730875
# Episode 1018, Reward: -5.462736571513181
# Episode 1019, Reward: -5.4475596877150245
# Episode 1020, Reward: -5.458769384136595
# Episode 1021, Reward: -3.0
# Episode 1022, Reward: -3.0
# Episode 1023, Reward: -5.466233727551243
# Episode 1024, Reward: -5.473895419015992
# Episode 1025, Reward: -3.0
# Episode 1026, Reward: -3.0
# Episode 1027, Reward: -3.0
# Episode 1028, Reward: -5.480239525617334
# Episode 1029, Reward: -3.0
# Episode 1030, Reward: -4.404374775760697
# Episode 1031, Reward: -5.475330661778639
# Episode 1032, Reward: -3.0
# Episode 1033, Reward: -3.0
# Episode 1034, Reward: -3.0
# Episode 1035, Reward: -5.4706069867995115
# Episode 1036, Reward: -3.0
# Episode 1037, Reward: -3.0
# Episode 1038, Reward: -5.457577296197827
# Episode 1039, Reward: -3.0
# Episode 1040, Reward: -5.472566182828727
# Episode 1041, Reward: -3.0
# Episode 1042, Reward: -5.455762534754319
# Episode 1043, Reward: -5.4794895579298455
# Episode 1044, Reward: -5.509163925373334
# Episode 1045, Reward: -3.0
# Episode 1046, Reward: -3.0
# Episode 1047, Reward: -3.0
# Episode 1048, Reward: -3.0
# Episode 1049, Reward: -3.0
# Episode 1050, Reward: -5.461680550218118
# Episode 1051, Reward: -3.0
# Episode 1052, Reward: -5.457832917849607
# Episode 1053, Reward: -5.442051995332895
# Episode 1054, Reward: -5.432130655986675
# Episode 1055, Reward: -5.47574629683794
# Episode 1056, Reward: -5.468657112726286
# Episode 1057, Reward: -5.471551209991174
# Episode 1058, Reward: -5.46139593575257
# Episode 1059, Reward: -5.489739136224294
# Episode 1060, Reward: -3.0
# Episode 1061, Reward: -5.463716151789015
# Episode 1062, Reward: -5.468637878274144
# Episode 1063, Reward: -3.0
# Episode 1064, Reward: -5.464817217347253
# Episode 1065, Reward: -5.452042855778077
# Episode 1066, Reward: -3.0
# Episode 1067, Reward: -5.490426089485748
# Episode 1068, Reward: -5.444271451836489
# Episode 1069, Reward: -5.4617005370065215
# Episode 1070, Reward: -5.511433694943019
# Episode 1071, Reward: -5.470886916085707
# Episode 1072, Reward: -3.0
# Episode 1073, Reward: -3.0
# Episode 1074, Reward: -5.440067781696586
# Episode 1075, Reward: -3.0
# Episode 1076, Reward: -5.460401568821422
# Episode 1077, Reward: -5.467529385274556
# Episode 1078, Reward: -5.45634866581508
# Episode 1079, Reward: -3.0
# Episode 1080, Reward: -5.475446050173997
# Episode 1081, Reward: -5.478240944425297
# Episode 1082, Reward: -5.489242436201897
# Episode 1083, Reward: -4.431516022829579
# Episode 1084, Reward: -3.0
# Episode 1085, Reward: -3.0
# Episode 1086, Reward: -3.0
# Episode 1087, Reward: -3.0
# Episode 1088, Reward: -5.506539055206685
# Episode 1089, Reward: -3.0
# Episode 1090, Reward: -5.469892261468573
# Episode 1091, Reward: -3.0
# Episode 1092, Reward: -3.0
# Episode 1093, Reward: -3.0
# Episode 1094, Reward: -5.455095452811846
# Episode 1095, Reward: -5.482089701594222
# Episode 1096, Reward: -5.452180950055102
# Episode 1097, Reward: -3.0
# Episode 1098, Reward: -3.0
# Episode 1099, Reward: -5.4543338749117165
# Episode 1100, Reward: -5.492346539980213
# Episode 1101, Reward: -5.4768836624191
# Episode 1102, Reward: -4.407763494555806
# Episode 1103, Reward: -5.464286805594403
# Episode 1104, Reward: -5.479381640617706
# Episode 1105, Reward: -5.475877167552398
# Episode 1106, Reward: -5.4992648295680056
# Episode 1107, Reward: -5.446029158102393
# Episode 1108, Reward: -5.474874717418139
# Episode 1109, Reward: -4.4100971838723755
# Episode 1110, Reward: -3.0
# Episode 1111, Reward: -3.0
# Episode 1112, Reward: -5.474685230427828
# Episode 1113, Reward: -5.4747362181952575
# Episode 1114, Reward: -5.515782952926894
# Episode 1115, Reward: -4.423531437821367
# Episode 1116, Reward: -5.506172932233079
# Episode 1117, Reward: -5.472183809361479
# Episode 1118, Reward: -5.459937636027612
# Episode 1119, Reward: -3.0
# Episode 1120, Reward: -5.447690692292878
# Episode 1121, Reward: -3.0
# Episode 1122, Reward: -5.4759419244251575
# Episode 1123, Reward: -5.446795602734539
# Episode 1124, Reward: -3.0
# Episode 1125, Reward: -5.468010694040428
# Episode 1126, Reward: -4.420247404243467
# Episode 1127, Reward: -5.4889076224372975
# Episode 1128, Reward: -5.462647014596623
# Episode 1129, Reward: -3.0
# Episode 1130, Reward: -5.505052377990351
# Episode 1131, Reward: -3.0
# Episode 1132, Reward: -3.0
# Episode 1133, Reward: -3.0
# Episode 1134, Reward: -5.489339084448934
# Episode 1135, Reward: -3.0
# Episode 1136, Reward: -3.0
# Episode 1137, Reward: -3.0
# Episode 1138, Reward: -3.0
# Episode 1139, Reward: -5.45416158569785
# Episode 1140, Reward: -3.0
# Episode 1141, Reward: -3.0
# Episode 1142, Reward: -3.0
# Episode 1143, Reward: -5.454928822249334
# Episode 1144, Reward: -3.0
# Episode 1145, Reward: -3.0
# Episode 1146, Reward: -3.0
# Episode 1147, Reward: -3.0
# Episode 1148, Reward: -5.464605633420471
# Episode 1149, Reward: -3.0
# Episode 1150, Reward: -3.0
# Episode 1151, Reward: -5.451772290187353
# Episode 1152, Reward: -5.4579092479744595
# Episode 1153, Reward: -3.0
# Episode 1154, Reward: -3.0
# Episode 1155, Reward: -5.475023883255572
# Episode 1156, Reward: -3.0
# Episode 1157, Reward: -3.0
# Episode 1158, Reward: -5.469853587719662
# Episode 1159, Reward: -5.476751971370982
# Episode 1160, Reward: -3.0
# Episode 1161, Reward: -3.0
# Episode 1162, Reward: -3.0
# Episode 1163, Reward: -3.0
# Episode 1164, Reward: -3.0
# Episode 1165, Reward: -5.45700729527074
# Episode 1166, Reward: -4.403781433244072
# Episode 1167, Reward: -3.0
# Episode 1168, Reward: -5.456304453355073
# Episode 1169, Reward: -5.439893306255726
# Episode 1170, Reward: -5.475730132514432
# Episode 1171, Reward: -3.0
# Episode 1172, Reward: -3.0
# Episode 1173, Reward: -5.464798372588441
# Episode 1174, Reward: -5.476106858977229
# Episode 1175, Reward: -5.50136429722726
# Episode 1176, Reward: -3.0
# Episode 1177, Reward: -5.492205535465935
# Episode 1178, Reward: -3.0
# Episode 1179, Reward: -5.485002176278257
# Episode 1180, Reward: -3.0
# Episode 1181, Reward: -5.468466031328824
# Episode 1182, Reward: -3.0
# Episode 1183, Reward: -5.47032748227248
# Episode 1184, Reward: -5.515524509518234
# Episode 1185, Reward: -5.469719386519532
# Episode 1186, Reward: -4.4191368557022805
# Episode 1187, Reward: -5.48130268162352
# Episode 1188, Reward: -3.0
# Episode 1189, Reward: -3.0
# Episode 1190, Reward: -5.451834146163854
# Episode 1191, Reward: -3.0
# Episode 1192, Reward: -5.481290642649796
# Episode 1193, Reward: -3.0
# Episode 1194, Reward: -3.0
# Episode 1195, Reward: -5.4549719588045065
# Episode 1196, Reward: -5.457567713789631
# Episode 1197, Reward: -5.46167145496033
# Episode 1198, Reward: -3.0
# Episode 1199, Reward: -5.477581669470322
# Episode 1200, Reward: -3.0
# Episode 1201, Reward: -4.408603315524603
# Episode 1202, Reward: -5.442455799160548
# Episode 1203, Reward: -3.0
# Episode 1204, Reward: -3.0
# Episode 1205, Reward: -3.0
# Episode 1206, Reward: -3.0
# Episode 1207, Reward: -5.474938769028231
# Episode 1208, Reward: -5.455187242888485
# Episode 1209, Reward: -3.0
# Episode 1210, Reward: -5.507734901098331
# Episode 1211, Reward: -3.0
# Episode 1212, Reward: -3.0
# Episode 1213, Reward: -3.0
# Episode 1214, Reward: -5.450509912891023
# Episode 1215, Reward: -3.0
# Episode 1216, Reward: -3.0
# Episode 1217, Reward: -3.0
# Episode 1218, Reward: -3.0
# Episode 1219, Reward: -5.448394166170752
# Episode 1220, Reward: -4.427224260471512
# Episode 1221, Reward: -5.471475776211285
# Episode 1222, Reward: -3.0
# Episode 1223, Reward: -3.0
# Episode 1224, Reward: -3.0
# Episode 1225, Reward: -5.462141527770754
# Episode 1226, Reward: -3.0
# Episode 1227, Reward: -5.466948004055882
# Episode 1228, Reward: -5.44571972897223
# Episode 1229, Reward: -3.0
# Episode 1230, Reward: -5.452154007266608
# Episode 1231, Reward: -4.435137782048469
# Episode 1232, Reward: -3.0
# Episode 1233, Reward: -3.0
# Episode 1234, Reward: -5.432735640147365
# Episode 1235, Reward: -5.45263757187265
# Episode 1236, Reward: -5.453678125979971
# Episode 1237, Reward: -5.447356841567281
# Episode 1238, Reward: -5.4717395131690765
# Episode 1239, Reward: -3.0
# Episode 1240, Reward: -3.0
# Episode 1241, Reward: -3.0
# Episode 1242, Reward: -3.0
# Episode 1243, Reward: -3.0
# Episode 1244, Reward: -3.0
# Episode 1245, Reward: -5.461445259811199
# Episode 1246, Reward: -3.0
# Episode 1247, Reward: -3.0
# Episode 1248, Reward: -5.508686273916904
# Episode 1249, Reward: -5.474895661203241
# Episode 1250, Reward: -3.0
# Episode 1251, Reward: -5.454809219786901
# Episode 1252, Reward: -3.0
# Episode 1253, Reward: -3.0
# Episode 1254, Reward: -5.493035033202397
# Episode 1255, Reward: -4.411675292767185
# Episode 1256, Reward: -5.4658447317769525
# Episode 1257, Reward: -5.474123128456368
# Episode 1258, Reward: -5.48203044391499
# Episode 1259, Reward: -3.0
# Episode 1260, Reward: -3.0
# Episode 1261, Reward: -5.459037540311864
# Episode 1262, Reward: -5.461503432432267
# Episode 1263, Reward: -5.472135059267028
# Episode 1264, Reward: -5.455021950177825
# Episode 1265, Reward: -3.0
# Episode 1266, Reward: -3.0
# Episode 1267, Reward: -5.481412559084983
# Episode 1268, Reward: -5.481751421031211
# Episode 1269, Reward: -3.0
# Episode 1270, Reward: -3.0
# Episode 1271, Reward: -4.396846596725053
# Episode 1272, Reward: -5.510712759284057
# Episode 1273, Reward: -3.0
# Episode 1274, Reward: -5.461688625633973
# Episode 1275, Reward: -3.0
# Episode 1276, Reward: -5.472505296052961
# Episode 1277, Reward: -3.0
# Episode 1278, Reward: -5.4590878051731115
# Episode 1279, Reward: -3.0
# Episode 1280, Reward: -3.0
# Episode 1281, Reward: -3.0
# Episode 1282, Reward: -3.0
# Episode 1283, Reward: -5.488240963774321
# Episode 1284, Reward: -5.467925482361364
# Episode 1285, Reward: -5.523762699447027
# Episode 1286, Reward: -3.0
# Episode 1287, Reward: -4.433698521054973
# Episode 1288, Reward: -3.0
# Episode 1289, Reward: -5.471303221196753
# Episode 1290, Reward: -5.438739449643995
# Episode 1291, Reward: -3.0
# Episode 1292, Reward: -3.0
# Episode 1293, Reward: -3.0
# Episode 1294, Reward: -3.0
# Episode 1295, Reward: -3.0
# Episode 1296, Reward: -3.0
# Episode 1297, Reward: -4.4190982420221365
# Episode 1298, Reward: -5.481202693667353
# Episode 1299, Reward: -5.459368869618
# Episode 1300, Reward: -3.0
# Episode 1301, Reward: -3.0
# Episode 1302, Reward: -3.0
# Episode 1303, Reward: -5.456243358430936
# Episode 1304, Reward: -5.436673753111549
# Episode 1305, Reward: -3.0
# Episode 1306, Reward: -3.0
# Episode 1307, Reward: -3.0
# Episode 1308, Reward: -3.0
# Episode 1309, Reward: -5.440822831174098
# Episode 1310, Reward: -4.432911063937805
# Episode 1311, Reward: -3.0
# Episode 1312, Reward: -3.0
# Episode 1313, Reward: -4.389925062782778
# Episode 1314, Reward: -3.0
# Episode 1315, Reward: -5.467137413416144
# Episode 1316, Reward: -3.0
# Episode 1317, Reward: -3.0
# Episode 1318, Reward: -5.471518419196194
# Episode 1319, Reward: -3.0
# Episode 1320, Reward: -5.464642718308664
# Episode 1321, Reward: -3.0
# Episode 1322, Reward: -3.0
# Episode 1323, Reward: -3.0
# Episode 1324, Reward: -3.0
# Episode 1325, Reward: -3.0
# Episode 1326, Reward: -5.451833303943548
# Episode 1327, Reward: -3.0
# Episode 1328, Reward: -3.0
# Episode 1329, Reward: -3.0
# Episode 1330, Reward: -5.466689634947217
# Episode 1331, Reward: -5.4795302055173405
# Episode 1332, Reward: -3.0
# Episode 1333, Reward: -3.0
# Episode 1334, Reward: -3.0
# Episode 1335, Reward: -3.0
# Episode 1336, Reward: -5.465652505854523
# Episode 1337, Reward: -3.0
# Episode 1338, Reward: -5.4399114426228685
# Episode 1339, Reward: -3.0
# Episode 1340, Reward: -3.0
# Episode 1341, Reward: -5.454728424930188
# Episode 1342, Reward: -3.0
# Episode 1343, Reward: -5.446085104307562
# Episode 1344, Reward: -4.429550507914927
# Episode 1345, Reward: -5.471692903883899
# Episode 1346, Reward: -3.0
# Episode 1347, Reward: -3.0
# Episode 1348, Reward: -3.0
# Episode 1349, Reward: -3.0
# Episode 1350, Reward: -5.475951240587515
# Episode 1351, Reward: -5.491023760588329
# Episode 1352, Reward: -3.0
# Episode 1353, Reward: -3.0
# Episode 1354, Reward: -3.0
# Episode 1355, Reward: -3.0
# Episode 1356, Reward: -3.0
# Episode 1357, Reward: -5.4653136622942515
# Episode 1358, Reward: -3.0
# Episode 1359, Reward: -5.453401208847342
# Episode 1360, Reward: -5.45236760636398
# Episode 1361, Reward: -3.0
# Episode 1362, Reward: -5.456118563129993
# Episode 1363, Reward: -4.43155026159034
# Episode 1364, Reward: -5.494628565505778
# Episode 1365, Reward: -5.456704567573491
# Episode 1366, Reward: -5.453300567779685
# Episode 1367, Reward: -3.0
# Episode 1368, Reward: -4.394633332580553
# Episode 1369, Reward: -5.465922138693669
# Episode 1370, Reward: -3.0
# Episode 1371, Reward: -3.0
# Episode 1372, Reward: -5.447994702760052
# Episode 1373, Reward: -4.433748908253272
# Episode 1374, Reward: -3.0
# Episode 1375, Reward: -3.0
# Episode 1376, Reward: -5.444628692928072
# Episode 1377, Reward: -3.0
# Episode 1378, Reward: -5.468316561038751
# Episode 1379, Reward: -4.421479079040017
# Episode 1380, Reward: -3.0
# Episode 1381, Reward: -5.46470169508461
# Episode 1382, Reward: -5.446139379221434
# Episode 1383, Reward: -5.465374426022011
# Episode 1384, Reward: -3.0
# Episode 1385, Reward: -3.0
# Episode 1386, Reward: -3.0
# Episode 1387, Reward: -3.0
# Episode 1388, Reward: -5.472730281770861
# Episode 1389, Reward: -3.0
# Episode 1390, Reward: -5.466819562918364
# Episode 1391, Reward: -5.462323056438709
# Episode 1392, Reward: -4.4281392790393745
# Episode 1393, Reward: -3.0
# Episode 1394, Reward: -3.0
# Episode 1395, Reward: -5.4851173108544105
# Episode 1396, Reward: -3.0
# Episode 1397, Reward: -5.455211854395387
# Episode 1398, Reward: -4.422975390690161
# Episode 1399, Reward: -5.478080531318698
# Episode 1400, Reward: -5.4388029670727684
# Episode 1401, Reward: -3.0
# Episode 1402, Reward: -3.0
# Episode 1403, Reward: -3.0
# Episode 1404, Reward: -3.0
# Episode 1405, Reward: -3.0
# Episode 1406, Reward: -5.478276766805918
# Episode 1407, Reward: -3.0
# Episode 1408, Reward: -3.0
# Episode 1409, Reward: -5.464847792625121
# Episode 1410, Reward: -5.4420951811129745
# Episode 1411, Reward: -3.0
# Episode 1412, Reward: -3.0
# Episode 1413, Reward: -3.0
# Episode 1414, Reward: -3.0
# Episode 1415, Reward: -5.476189932448984
# Episode 1416, Reward: -4.420364341866774
# Episode 1417, Reward: -5.4552024125762735
# Episode 1418, Reward: -4.429773958805361
# Episode 1419, Reward: -5.4404994397470645
# Episode 1420, Reward: -3.0
# Episode 1421, Reward: -3.0
# Episode 1422, Reward: -5.437461807667287
# Episode 1423, Reward: -4.415173831415353
# Episode 1424, Reward: -5.460102107544088
# Episode 1425, Reward: -3.0
# Episode 1426, Reward: -5.462136066527806
# Episode 1427, Reward: -5.469996806242252
# Episode 1428, Reward: -3.0
# Episode 1429, Reward: -3.0
# Episode 1430, Reward: -5.4654044199878395
# Episode 1431, Reward: -5.487429511105773
# Episode 1432, Reward: -3.0
# Episode 1433, Reward: -3.0
# Episode 1434, Reward: -5.476054523973515
# Episode 1435, Reward: -3.0
# Episode 1436, Reward: -3.0
# Episode 1437, Reward: -3.0
# Episode 1438, Reward: -5.453980134152701
# Episode 1439, Reward: -5.464992487094527
# Episode 1440, Reward: -5.486852697296598
# Episode 1441, Reward: -3.0
# Episode 1442, Reward: -3.0
# Episode 1443, Reward: -5.455424039570161
# Episode 1444, Reward: -5.45888522691957
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 42
#      39     # 保存最终模型
#      40     agent.save_model("td3_gridworld_final")
# ---> 42 train_main()
#
# Cell In[11], line 32, in train_main()
#      30 # 开始训练
#      31 print("Starting training...")
# ---> 32 train_td3(
#      33     env=env,
#      34     agent=agent,
#      35     episodes=2000,
#      36     max_steps=10000,
#      37 )
#      39 # 保存最终模型
#      40 agent.save_model("td3_gridworld_final")
#
# Cell In[8], line 28, in train_td3(env, agent, episodes, max_steps, batch_size, save_every)
#      25 episode_reward += reward
#      27 # 训练
# ---> 28 agent.train(batch_size)
#      30 if done:
#      31     break
#
# Cell In[6], line 71, in TD3.train(self, batch_size)
#      69 # 优化 critic
#      70 self.critic_optimizer.zero_grad()
# ---> 71 critic_loss.backward()
#      72 self.critic_optimizer.step()
#      74 # Delayed policy updates
#
# File c:\ProgramData\anaconda3\envs\lab\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\ProgramData\anaconda3\envs\lab\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\ProgramData\anaconda3\envs\lab\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
def main_test():
    # 初始化环境
    grid_map = np.loadtxt("grid_map_final.txt", dtype=int)
    nodes=[(51, 12), (55, 23), (55, 30), (32, 47), (9, 50), (9, 64)]
    env = GridWorld(grid_map , start=(58, 5) , goal=(51, 12),goal_list=nodes)
    
    state_dim = env.get_state().shape[0]  # 应为 51
    action_dim = 2  # 连续动作：dx 和 dy
    max_action = 1.0  # 动作范围 [-1, 1]
    
    # 初始化 TD3 Agent
    agent = TD3(state_dim, action_dim, max_action, device="cuda" if torch.cuda.is_available() else "cpu")
    
    # 加载训练好的模型
    trained_model_path = "td3_gridworld_final"  # 模型路径
    agent.load_model(trained_model_path)
    
    # 测试多个回合
    success_runs = check_trained_model_num_td3(env, agent, trained_model_path, max_steps=1000, num_runs=100)
    
    # 测试并动态渲染单次
    check_trained_model_td3(env, agent, trained_model_path, max_steps=1000)

main_test()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1612\531637304.py:100: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.actor.load_state_dict(torch.load(filename + "_actor.pth"))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1612\531637304.py:101: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.critic.load_state_dict(torch.load(filename + "_critic.pth"))
# Loaded model from td3_gridworld_final_actor.pth and td3_gridworld_final_critic.pth
# Run 1: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 2: Reward = 14.955437269089117, Steps = 23, Success = True
# Run 3: Reward = 9.998472894139216, Steps = 28, Success = False
# Run 4: Reward = -5.186766226810603, Steps = 14, Success = False
# Run 5: Reward = 16.16634039368835, Steps = 24, Success = True
# Run 6: Reward = 9.998472894139216, Steps = 28, Success = False
# Run 7: Reward = 21.135962740260062, Steps = 24, Success = True
# Run 8: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 9: Reward = 20.907906854607408, Steps = 24, Success = True
# Run 10: Reward = 12.294992283396553, Steps = 22, Success = True
# Run 11: Reward = 12.75574032921128, Steps = 33, Success = True
# Run 12: Reward = -4.668823064451061, Steps = 3, Success = False
# Run 13: Reward = 6.310747876838583, Steps = 13, Success = False
# Run 14: Reward = 21.137571322097, Steps = 23, Success = True
# Run 15: Reward = -91.79765708798266, Steps = 219, Success = False
# Run 16: Reward = 16.779549365858045, Steps = 23, Success = True
# Run 17: Reward = 21.826270293751687, Steps = 24, Success = True
# Run 18: Reward = -480.48746925468157, Steps = 1000, Success = False
# Run 19: Reward = -387.1054205039042, Steps = 1000, Success = False
# Run 20: Reward = 19.526340700092312, Steps = 24, Success = True
# Run 21: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 22: Reward = 12.417290113894925, Steps = 25, Success = True
# Run 23: Reward = 11.056866533601172, Steps = 25, Success = True
# Run 24: Reward = 13.92706365707955, Steps = 22, Success = True
# Run 25: Reward = 21.447853088345507, Steps = 23, Success = True
# Run 26: Reward = 21.52597577918785, Steps = 25, Success = True
# Run 27: Reward = 15.88800102303519, Steps = 25, Success = True
# Run 28: Reward = 9.403190369411362, Steps = 17, Success = False
# Run 29: Reward = 10.847041006106192, Steps = 17, Success = True
# Run 30: Reward = 21.82634070009231, Steps = 24, Success = True
# Run 31: Reward = 20.535089867959375, Steps = 25, Success = True
# Run 32: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 33: Reward = 19.010082396059982, Steps = 23, Success = True
# Run 34: Reward = 19.238363227297782, Steps = 25, Success = True
# Run 35: Reward = 0.89410274973761, Steps = 7, Success = False
# Run 36: Reward = 22.23868573387297, Steps = 24, Success = True
# Run 37: Reward = 21.046041818267938, Steps = 26, Success = True
# Run 38: Reward = 12.417290113894925, Steps = 25, Success = True
# Run 39: Reward = 19.36129990333682, Steps = 23, Success = True
# Run 40: Reward = 12.950782759419937, Steps = 23, Success = True
# Run 41: Reward = 21.38695150291358, Steps = 24, Success = True
# Run 42: Reward = 18.53770276251635, Steps = 25, Success = True
# Run 43: Reward = 17.130639135507664, Steps = 25, Success = True
# Run 44: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 45: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 46: Reward = 17.6540496460715, Steps = 24, Success = True
# Run 47: Reward = 18.698350507655306, Steps = 23, Success = True
# Run 48: Reward = 18.36263520293219, Steps = 23, Success = True
# Run 49: Reward = 8.218176443679278, Steps = 20, Success = False
# Run 50: Reward = -513.4456718287986, Steps = 442, Success = False
# Run 51: Reward = 2.9506635983094096, Steps = 12, Success = False
# Run 52: Reward = 12.138118779797935, Steps = 26, Success = True
# Run 53: Reward = 10.151276297358027, Steps = 30, Success = True
# Run 54: Reward = 14.185589383406548, Steps = 24, Success = True
# Run 55: Reward = 16.156037473701083, Steps = 29, Success = True
# Run 56: Reward = 17.463780375024292, Steps = 24, Success = True
# Run 57: Reward = 17.488267337211937, Steps = 26, Success = True
# Run 58: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 59: Reward = -3.7372621001962205, Steps = 4, Success = False
# Run 60: Reward = 1.6491218574062128, Steps = 9, Success = False
# Run 61: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 62: Reward = 14.903142556001264, Steps = 28, Success = True
# Run 63: Reward = 4.693767817176315, Steps = 18, Success = False
# Run 64: Reward = 21.636340700092312, Steps = 24, Success = True
# Run 65: Reward = 17.656340717306154, Steps = 24, Success = True
# Run 66: Reward = 20.856050734482714, Steps = 26, Success = True
# Run 67: Reward = 13.940748519136847, Steps = 27, Success = True
# Run 68: Reward = -2.4258972502623894, Steps = 7, Success = False
# Run 69: Reward = -16.060421016053454, Steps = 42, Success = False
# Run 70: Reward = 17.955811530007548, Steps = 22, Success = True
# Run 71: Reward = -48.8382724778554, Steps = 81, Success = False
# Run 72: Reward = 17.642468985339523, Steps = 24, Success = True
# Run 73: Reward = -15.142350150320222, Steps = 38, Success = False
# Run 74: Reward = -457.5666279414111, Steps = 1000, Success = False
# Run 75: Reward = 22.29512666025183, Steps = 22, Success = True
# Run 76: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 77: Reward = 20.476327817405753, Steps = 24, Success = True
# Run 78: Reward = 18.32667691106422, Steps = 28, Success = True
# Run 79: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 80: Reward = 21.18867795306111, Steps = 24, Success = True
# Run 81: Reward = 15.959534146492004, Steps = 24, Success = True
# Run 82: Reward = 22.014875821885262, Steps = 24, Success = True
# Run 83: Reward = 7.798724840241778, Steps = 29, Success = False
# Run 84: Reward = 14.324211705375678, Steps = 25, Success = True
# Run 85: Reward = 16.12155227536123, Steps = 26, Success = True
# Run 86: Reward = 21.204132994196538, Steps = 22, Success = True
# Run 87: Reward = 17.1664434895268, Steps = 24, Success = True
# Run 88: Reward = 6.24273393178396, Steps = 11, Success = False
# Run 89: Reward = 21.61894542503308, Steps = 24, Success = True
# Run 90: Reward = -3.837849930201452, Steps = 2, Success = False
# Run 91: Reward = 8.91494358244157, Steps = 23, Success = False
# Run 92: Reward = 22.01634070009231, Steps = 24, Success = True
# Run 93: Reward = 19.61923968161086, Steps = 24, Success = True
# Run 94: Reward = 20.573173626018473, Steps = 23, Success = True
# Run 95: Reward = 16.01626762266715, Steps = 25, Success = True
# Run 96: Reward = 13.792631994335295, Steps = 24, Success = True
# Run 97: Reward = -4.668839563743811, Steps = 3, Success = False
# Run 98: Reward = 20.97648578583583, Steps = 24, Success = True
# Run 99: Reward = 17.92687431662958, Steps = 21, Success = True
# Run 100: Reward = 8.05042403347543, Steps = 12, Success = False
# 测试完成。成功次数: 0/100
# Loaded model from td3_gridworld_final_actor.pth and td3_gridworld_final_critic.pth
# 测试完成。总奖励: 13.272715291369135, 步数: 23

# %%
check_trained_model_td3(env, agent, "td3_gridworld_final", max_steps=1000)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1612\531637304.py:100: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.actor.load_state_dict(torch.load(filename + "_actor.pth"))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1612\531637304.py:101: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.critic.load_state_dict(torch.load(filename + "_critic.pth"))
# Loaded model from td3_gridworld_final
# Test Completed. Total Reward: 20.687011300547542, Steps Taken: 26
# 仿真完成，耗时 37.21 秒
